# %% [markdown]
# DD2437 - Artificial Neural Networks and Deep Architectures
# Lab assignement 1a - Classifcation with a single-layer perceptron

# %%
import numpy as np
import random as rd
from perceptron import *
import random

random.seed(1)

n = 100
mA = np.array([[3.0], [0.3]])
mB = np.array([[0.0], [-0.1]])
sigmaA = 0.4
sigmaB = 0.3

data_type = "linear"
#data_type = "nonlinear"
rng = np.random.default_rng()
plt.figure()
plt.title("Linearly separable dataset")
X, T = new_data(mA, mB, sigmaA, sigmaB, n, data_type, rng)
#X, T = subsample(n, 1, mA, mB, sigmaA, sigmaB)
#X, T = subsample(n, 2, mA, mB, sigmaA, sigmaB)
#X, T = subsample(n, 3, mA, mB, sigmaA, sigmaB)
#X, T = subsample(n, 4, mA, mB, sigmaA, sigmaB)
# Out:
# EPOCH=0, accuracy:
# [[100.   0.]
#  [  0. 100.]]
# EPOCH=1, accuracy:
# [[  0. 100.]
#  [  0. 100.]]
# EPOCH=2, accuracy:
# [[100.   0.]
#  [  0. 100.]]
# EPOCH=3, accuracy:
# [[  0. 100.]
#  [100.   0.]]
# EPOCH=4, accuracy:
# [[100.   0.]
#  [  0. 100.]]
# EPOCH=5, accuracy:
# [[  0. 100.]
#  [100.   0.]]
# EPOCH=6, accuracy:
# [[100.   0.]
#  [  0. 100.]]
# EPOCH=7, accuracy:
# [[  0. 100.]
#  [100.   0.]]
# EPOCH=8, accuracy:
# [[100.   0.]
#  [  0. 100.]]
# EPOCH=9, accuracy:
# [[  0. 100.]
#  [100.   0.]]
# EPOCH=10, accuracy:
# [[100.   0.]
#  [  0. 100.]]
# EPOCH=11, accuracy:
# [[  0. 100.]
#  [100.   0.]]
# EPOCH=12, accuracy:
# [[100.   0.]
#  [  0. 100.]]
# EPOCH=13, accuracy:
# [[  0. 100.]
#  [100.   0.]]
# EPOCH=14, accuracy:
# [[100.   0.]
#  [  0. 100.]]
# EPOCH=15, accuracy:
# [[  0. 100.]
#  [100.   0.]]
# EPOCH=16, accuracy:
# [[100.   0.]
#  [  0. 100.]]
# EPOCH=17, accuracy:
# [[  0. 100.]
#  [100.   0.]]
# EPOCH=18, accuracy:
# [[100.   0.]
#  [  0. 100.]]
# EPOCH=19, accuracy:
# [[  0. 100.]
#  [100.   0.]]

# %%
#DELTA BATCH
plt.ion()

epochs = 20
eta = 1e-2

W = rng.random((3))
N = X.shape[1]
data_type = "linear"

mse = []
accuracyA = []
accuracyB = []
for epoch in range(epochs):

    W += - eta * (W@X - T) @ X.T

    mse.append(np.mean((W @ X - T) ** 2))
    plt.clf()
    plot_data(X, T)
    plot_boundaries(W)
    plt.title(f"epoch:{epoch}")
    plt.pause(0.2)

    print(f"EPOCH={epoch}, accuracy:")
    accuracy = missclassified_rate(X, T, W)
    print(accuracy)
    accuracyA.append(accuracy[1, 1])
    accuracyB.append(accuracy[0, 0])


plt.ioff()

plt.figure()
plt.plot(range(epochs), mse)
plt.title("MSE")
plt.show()

plt.figure()
plt.plot(range(epochs), accuracyA)
plt.plot(range(epochs), accuracyB)
plt.title("Accuracy")
plt.legend(["B", "A"])
plt.show()
# Out:
# EPOCH=0, accuracy:
# [[100.   0.]
#  [100.   0.]]
# EPOCH=1, accuracy:
# [[ 21.  79.]
#  [  0. 100.]]
# EPOCH=2, accuracy:
# [[ 82.  18.]
#  [100.   0.]]
# EPOCH=3, accuracy:
# [[ 18.  82.]
#  [  0. 100.]]
# EPOCH=4, accuracy:
# [[ 82.  18.]
#  [100.   0.]]
# EPOCH=5, accuracy:
# [[ 18.  82.]
#  [  0. 100.]]
# EPOCH=6, accuracy:
# [[ 82.  18.]
#  [100.   0.]]
# EPOCH=7, accuracy:
# [[ 18.  82.]
#  [  0. 100.]]
# EPOCH=8, accuracy:
# [[ 82.  18.]
#  [100.   0.]]
# EPOCH=9, accuracy:
# [[ 18.  82.]
#  [  0. 100.]]
# EPOCH=10, accuracy:
# [[ 82.  18.]
#  [100.   0.]]
# EPOCH=11, accuracy:
# [[ 18.  82.]
#  [  0. 100.]]
# EPOCH=12, accuracy:
# [[ 82.  18.]
#  [100.   0.]]
# EPOCH=13, accuracy:
# [[ 18.  82.]
#  [  0. 100.]]
# EPOCH=14, accuracy:
# [[ 82.  18.]
#  [100.   0.]]
# EPOCH=15, accuracy:
# [[ 18.  82.]
#  [  0. 100.]]
# EPOCH=16, accuracy:
# [[ 82.  18.]
#  [100.   0.]]
# EPOCH=17, accuracy:
# [[ 18.  82.]
#  [  0. 100.]]
# EPOCH=18, accuracy:
# [[ 82.  18.]
#  [100.   0.]]
# EPOCH=19, accuracy:
# [[ 18.  82.]
#  [  0. 100.]]

# %%
#PERCEPTRON ONLINE
plt.ion()

mse = []
accuracyA = []
accuracyB = []
for epoch in range(epochs):
    for i in range(N):
        y_prime = W@X[:, i]
        if y_prime > 0:
            y = 1
        else:
            y = 0
        e = int(T[i]>0) - y
        deltaW = eta * e * X[:, i]
        W += deltaW

    mse.append(np.mean((W@X-T)**2))
    plt.clf()
    plot_data(X, T)
    plot_boundaries(W)
    plt.title(f"epoch:{epoch}")
    plt.pause(0.1)

    print(f"EPOCH={epoch}, accuracy:")
    accuracy = missclassified_rate(X, T, W)
    print(accuracy)
    accuracyA.append(accuracy[1, 1])
    accuracyB.append(accuracy[0, 0])

plt.ioff()

plt.figure()
plt.plot(range(epochs), mse)
plt.title("MSE")
plt.grid(True)
plt.show()

plt.figure()
plt.plot(range(epochs), accuracyA)
plt.plot(range(epochs), accuracyB)
plt.title("Accuracy")
plt.grid(True)
plt.show()
# Out:
# EPOCH=0, accuracy:
# [[ 18.  82.]
#  [  0. 100.]]
# EPOCH=1, accuracy:
# [[ 18.  82.]
#  [  0. 100.]]
# EPOCH=2, accuracy:
# [[ 18.  82.]
#  [  0. 100.]]
# EPOCH=3, accuracy:
# [[ 18.  82.]
#  [  0. 100.]]
# EPOCH=4, accuracy:
# [[ 18.  82.]
#  [  0. 100.]]
# EPOCH=5, accuracy:
# [[ 18.  82.]
#  [  0. 100.]]
# EPOCH=6, accuracy:
# [[ 18.  82.]
#  [  0. 100.]]
# EPOCH=7, accuracy:
# [[ 18.  82.]
#  [  0. 100.]]
# EPOCH=8, accuracy:
# [[ 18.  82.]
#  [  0. 100.]]
# EPOCH=9, accuracy:
# [[ 18.  82.]
#  [  0. 100.]]
# EPOCH=10, accuracy:
# [[ 18.  82.]
#  [  0. 100.]]
# EPOCH=11, accuracy:
# [[ 18.  82.]
#  [  0. 100.]]
# EPOCH=12, accuracy:
# [[ 18.  82.]
#  [  0. 100.]]
# EPOCH=13, accuracy:
# [[ 18.  82.]
#  [  0. 100.]]
# EPOCH=14, accuracy:
# [[ 18.  82.]
#  [  0. 100.]]
# EPOCH=15, accuracy:
# [[ 18.  82.]
#  [  0. 100.]]
# EPOCH=16, accuracy:
# [[ 18.  82.]
#  [  0. 100.]]
# EPOCH=17, accuracy:
# [[ 18.  82.]
#  [  0. 100.]]
# EPOCH=18, accuracy:
# [[ 18.  82.]
#  [  0. 100.]]
# EPOCH=19, accuracy:
# [[ 18.  82.]
#  [  0. 100.]]

# %%
#DELTA ONLINE
plt.ion()

mse = []

for epoch in range(epochs):
     for i in range(N):
         e = T[i] - W@X[:, i]
         deltaW = eta * e * X[:, i]
         W += deltaW
     mse.append(np.mean((W@X-T)**2))
     plt.clf()
     plot_data(X, T)
     plot_boundaries(W)
     plt.title(f"epoch:{epoch}")
     plt.pause(0.2)

plt.ioff()

plt.figure()
plt.plot(range(epochs), mse)
plt.title("MSE")
plt.show()

plt.figure()
plt.plot(range(epochs), accuracyA)
plt.plot(range(epochs), accuracyB)
plt.title("Accuracy")
plt.legend(["B", "A"])
plt.show()
